# %% [markdown]
# # Business Case

# %% [markdown]
# #### Forecast the Sales of a Product Category for a leading retailer in USA, based on the their Sales history and other related factors. Sales forecast would help the company to take necessary measures to plan their investments in future.

# %% [markdown]
# # ML Problem Statement

# %% [markdown]
# #### As target attribute is Sales (In Thousand Dollars) which is a continuous variable, so Machine Learning - Regression alogorithms can be used to solve the above mentioned Business Case.
# ##### As Regression algorithms are capable of forecasting the future values, so same can be applied to predict the Sales of a particular Product Category
# ##### Accurate Prediction of future Sales values would help the company to plan for their investment, backup, maintain their inventory so that maximum profit can be made on the salected product or be prepared in any case of any unseen problems or crisis.
#
# #### Error Metric to Use: Mean Absolute Percentage Error

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Data Available:
# ###### * Data: Train data | MacroEconomicData | Events_HolidaysData | WeatherData
# ###### * Target attribute: Sales (In Thousand Dollars)

# %% [markdown]
# ### Dimension:
# ######                * Train data: 252 rows and 4 columns
# ######                * MacroEconomicData: 96 columns and 18 columns
# ######                * Events_HolidaysData: 150 rows and 4 columns
# ######                * WeatherData: 2922 rows and 22 columns

# %% [markdown]
# ### Years columns
# ##### Year = '2009' to '2016' are present in these data sets: Train, MacroEconomicData, Events_HolidaysData, WeatherData
# ##### Year = '2009' to '2015' are present in train set

# %% [markdown]
# ### Merging is required on above data-sets to conert into a single Merge data-set
#
# ###### Dimension: 96 rows and 43 columns

# %% [markdown]
# ### Some missing values are present in MacroEconomicDatam, Weather and Train data, so Imputation is required

# %% [markdown]
# ### For Visualization, A separate Jupyter Notebook file is attached with final report for other visualization¶

# %% [markdown]
# ### Peformed various methods to handle data
# ##### Impute missing values
# ##### Train/Validation/Test Split of data
# ##### Standardiation of Numeric features
# ##### Drop Unimportant feature
# ##### Correlation Analysis

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ##### Data visualiation are performed on various independent features correlations and between target feature. Various plots are used for visualization based on the data such as Line graph, Bar plot, Histogram, Scatter plot, Density plot, Stacked Histogram, etc.
#
# ##### Visualization based on Target attribute and other independent attributes are displayed below
#
# ##### NOTE: A separate Jupyter Notebook file is attached with final report for other visualization

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Unemployment Rate.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs AvgUplandHarvested.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Export - Months (1 to 6) between 2012-2015.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Export - Months (7 to 12) between 2012-2015.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Events Holiday.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Federal Holiday.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs CommercialBankInterestRateonCreditCard.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs CommercialBankInterestRateonCreditCard_Overall.png", width=1000, height=100)

# %%
from IPython.display import Image
Image(filename="C:/Studies/INSOFE/Exams/PhD - ML/Original Data/Business/Sales vs Cotton Monthly Price US cents per Pound_2012-2015.png", width=1000, height=100)

# %% [markdown]
# # Models

# %% [markdown]
# ### Various Regression models are used to predict the Sales of a Product Category during year=2016 such as:
# ##### Linear Regression >> To start with applied Linear Regression to check initial prediction
# ##### Decision Tree Regressor >> To check better performance over Linear Regression
# ##### Random Forest Regressor >> As DT is overfitting and on Validation data not performing well, so used Random Forest
# ##### Random Forest Regressor with RandomizedSearchCV >> To Predict more accurately using hyper-parameter tuning
# ##### Adaboost >> Ensemble algorithm used to check on various samples to reduce Overfit of previous models
# ##### Adaboost with RandomizedSearchCV >> o Predict more accurately using hyper-parameter tuning
# ##### Gradient Boosting Regressor >> Ensemble algorithm used to check on various samples to reduce Overfit of previous models
# ##### Gradient Boosting Regressor with RandomizedSearchCV >> To Predict more accurately using hyper-parameter tuning
# ##### XGBoost Regressor >> Ensemble algorithm used to check on various samples to reduce Overfit of previous models

# %% [markdown]
# # Validation and Parameter Tuning

# %% [markdown]
# ### To Predict more accurately, hyper-parameter tuning is required for below models
#
# ##### Random Forest Regressor with RandomizedSearchCV >> 'bootstrap', 'criterion', 'n_estimators', 'max_features', 'max_depth'
# ##### Adaboost with RandomizedSearchCV >> n_estimators', 'max_features', 'max_depth', learning_rate
# ##### Gradient Boosting Regressor with RandomizedSearchCV >> n_estimators', 'max_features', 'max_depth',  learning_rate
# ##### XGBoost Regressor >> n_estimators', 'max_features', 'max_depth', learning_rate

# %% [markdown]
# # Summary & Conclusion

# %% [markdown]
# #### Sales of Clothing depends on various factors such as Weather condition, Economy of the country (US), Events, Demography, etc. and which is evident from the data which are  provided. Some of the attributes are directly and some are indirectly dependent on the Sales of clothing for year 2016. So, after applying various ML Regression Algorithms, we are abe to predict the Sales with upto 90.56% accuracy

# %% [markdown]
# ### Important Attributes found by applying various Machine Learning algorithms are:
# ##### 'Year', 'Month', 'Humidityavg', 'SeaLevelPressavg', 'Visibilityavg', 'Precipsum', 'CottonMonthlyPriceUScentsperPound', 'Averageuplandplanted', 'Averageuplandharvested', 'yieldperharvestedacre', 'Event', Sales from 2009-2015

# %% [markdown]
# ##### 'Event Holiday' - Very important feature in predicting Sales of Clothing in year 2016, so I would recommend the Retailer to increase investements during Event holidays, that would help them to increase reevenue

# %% [markdown]
# #### 'Averageuplandharvested' - Very imprtant for predicting Sales of Clothing in year 2016, as when Averageuplandharvested incraeases, Avg Sales increases, so I would recommend the Retailer to try to invest in increasing Average upland harvest (different domain), in order to make more money.

# %% [markdown]
# #### Focus on Unemployed Customer by providing more benefits to attract them, as they are not producing more Sales

# %% [markdown]
# # Appendices

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from math import sqrt
from scipy.stats import norm
from scipy import stats
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
import xgboost as xgb
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ## Dataset Loading

# %% [markdown]
# ##### Train Dataset

# %%
# Load Train dataset
train = pd.read_csv('Train.csv')

# Columns rename
train = train.rename(columns={'Sales(In ThousandDollars)' : 'Sales'})

# %%
# Create seperate dataframes for each 'ProductCategory' attribute

# WomenClothing
train_women = train.loc[train['ProductCategory']=='WomenClothing',:]

# MenClothing
train_men = train.loc[train['ProductCategory']=='MenClothing',:]

# OtherClothing
train_other = train.loc[train['ProductCategory']=='OtherClothing',:]

# %%
# View Dimension of all DFs
train_women.shape, train_men.shape, train_other.shape
# Out:
# ((84, 4), (84, 4), (84, 4))

# %%
# Create a new column as 'Year_Month'
train_women['Year_Month'] = train_women.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)
train_men['Year_Month'] = train_men.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)
train_other['Year_Month'] = train_other.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ##### Events Holidays Dataset

# %%
# Load the Events_HolidaysData dataset
event = pd.read_excel('Events_HolidaysData.xlsx')

# Column rename
event = pd.DataFrame(event.values, columns=['Year', 'MonthDate', 'EventsCount', 'DayCategory'])

# %%
# Split the 'Month-Day' attribute to 'Month' and 'Day' attributes
event['strDate'] = event.MonthDate.to_string(index=False).split('\n')
event['Month'] = (event['strDate'].str.split('-').str[1]).astype(int)
event['Day'] = (event['strDate'].str.split('-').str[0].str.slice(2,4)).astype(int)

# Drop unnecessary attributes
event.drop(['strDate', 'MonthDate'], axis=1, inplace=True)
event.drop('Day', axis=1, inplace=True)

# %%
# Dummify 'DayCategory' attribute and then drop 'DayCategory'
event = pd.concat([event.drop('DayCategory', axis=1), pd.get_dummies(event['DayCategory'])], axis=1)

# %%
# Replace EventsCount attribute with 1 values
event = event.replace([event['EventsCount']], 1)

# View top 5 data
event.head()
# Out:
#    Year  EventsCount  Month  Event  Federal Holiday
# 0  2009            1      1      0                1
# 1  2009            1      1      0                1
# 2  2009            1      2      1                0
# 3  2009            1      2      0                1
# 4  2009            1      4      1                0

# %%
# Aggregate 'EventsCount' attribute based on 'Year' an 'Month' attributes
event = event.groupby(['Year', 'Month']).agg({'EventsCount' : 'sum', 'Event' : 'sum', 'Federal Holiday' : 'sum'}).reset_index()

# %%
# Create na new column as 'Year_Month'
event['Year_Month'] = event.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)

# View top 10 data
event.head(10)   # Some records are missing due to no Holiday
# Out:
#    Year  Month  EventsCount  Event  Federal Holiday Year_Month
# 0  2009      1            2      0                2     2009_1
# 1  2009      2            2      1                1     2009_2
# 2  2009      4            1      1                0     2009_4
# 3  2009      5            2      1                1     2009_5
# 4  2009      6            1      1                0     2009_6
# 5  2009      7            2      0                2     2009_7
# 6  2009      9            1      0                1     2009_9
# 7  2009     10            2      1                1    2009_10
# 8  2009     11            2      0                2    2009_11
# 9  2009     12            3      2                1    2009_12

# %%
# Add missing data
col = ['Year','Month', 'EventsCount', 'Event', 'Federal Holiday', 'Year_Month']

event_missing = pd.DataFrame([[2009,3,0,0,0,'2009_3'], [2009,8,0,0,0,'2009_8'], [2010,3,0,0,0,'2010_3'],
                              [2010,8,0,0,0,'2010_8'], [2011,3,0,0,0,'2011_3'], [2011,8,0,0,0,'2011_8'],
                              [2012,3,0,0,0,'2012_3'], [2012,8,0,0,0,'2012_8'], [2013,4,0,0,0,'2013_4'],
                              [2013,8,0,0,0,'2013_8'], [2014,3,0,0,0,'2014_3'], [2014,8,0,0,0,'2014_8'],
                              [2015,3,0,0,0,'2015_3'], [2015,8,0,0,0,'2015_8'], [2016,8,0,0,0,'2016_8']], columns=col)
# View top 5 data
event_missing.head()
# Out:
#    Year  Month  EventsCount  Event  Federal Holiday Year_Month
# 0  2009      3            0      0                0     2009_3
# 1  2009      8            0      0                0     2009_8
# 2  2010      3            0      0                0     2010_3
# 3  2010      8            0      0                0     2010_8
# 4  2011      3            0      0                0     2011_3

# %%
# Append both dataframes
event = event.append(event_missing).sort_values(by=['Year', 'Month'], ascending=True)

# View dimension of combined dataframe
print('Dimension: ', event.shape)

# View top 12 data
event.head(12)
# Out:
# Dimension:  (96, 6)
#    Year  Month  EventsCount  Event  Federal Holiday Year_Month
# 0  2009      1            2      0                2     2009_1
# 1  2009      2            2      1                1     2009_2
# 0  2009      3            0      0                0     2009_3
# 2  2009      4            1      1                0     2009_4
# 3  2009      5            2      1                1     2009_5
# 4  2009      6            1      1                0     2009_6
# 5  2009      7            2      0                2     2009_7
# 1  2009      8            0      0                0     2009_8
# 6  2009      9            1      0                1     2009_9
# 7  2009     10            2      1                1    2009_10
# 8  2009     11            2      0                2    2009_11
# 9  2009     12            3      2                1    2009_12

# %% [markdown]
# ##### Weather Dataset

# %%
# Load the Weather dataset
weather = pd.ExcelFile('WeatherData.xlsx')

# Parse all sheets
weather2009 = weather.parse(0); weather2010 = weather.parse(1); weather2011 = weather.parse(2); 
weather2012 = weather.parse(3); weather2013 = weather.parse(4); weather2014 = weather.parse(5);
weather2015 = weather.parse(6); weather2016 = weather.parse(7)

# %%
# Concatenate all DFs
weather_all = pd.concat([weather2009, weather2010, weather2011, weather2012, weather2013, weather2014, weather2015, weather2016], axis=0)

# Dimension of combined DF
weather_all.shape
# Out:
# (2922, 23)

# %%
# View Columns
weather_all.head()
# Out:
#    Year Month  Day Temp high (°C) Temp avg (°C) Temp low (°C)  \
# 0  2009   Jan    1             -3            -6            -9
# 1  2009   Jan    2              1            -2            -5
# 2  2009   Jan    3              3             1            -2
# 3  2009   Jan    4              6             1            -4
# 4  2009   Jan    5              6             5             3
#
#   Dew Point high (°C) Dew Point avg (°C) Dew Point low (°C) Humidity (%) high  \
# 0                 -16                -17                -19                54
# 1                  -3                 -7                -17                78
# 2                  -5                 -9                -13                72
# 3                 -10                -12                -13                55
# 4                  -1                 -5                -16                62
#
#       ...      Sea Level Press. (hPa) avg Sea Level Press. (hPa) low  \
# ...

# %%
# Columns  rename
column = ['Year', 'Month', 'Day', 'Temphigh(°C)', 'Tempavg(°C)', 'Templow(°C)', 'DewPointhigh(°C)', 'DewPointavg(°C)', 
           'DewPointlow(°C)','Humidity(%)high', 'Humidity(%)avg', 'Humidity(%)low', 'SeaLevelPress(hPa)high', 
           'SeaLevelPress(hPa)avg', 'SeaLevelPress(hPa)low', 'Visibility(km)high', 'Visibility(km)avg', 'Visibility(km)low', 
           'Wind(km/h)low','Wind(km/h)avg', 'Wind(km/h)high', 'Precip(mm)sum', 'WeatherEvent']

weather_all = pd.DataFrame(weather_all.values, columns=column)

# Columns
weather_all.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Temphigh(°C)', 'Tempavg(°C)', 'Templow(°C)',
#        'DewPointhigh(°C)', 'DewPointavg(°C)', 'DewPointlow(°C)',
#        'Humidity(%)high', 'Humidity(%)avg', 'Humidity(%)low',
#        'SeaLevelPress(hPa)high', 'SeaLevelPress(hPa)avg',
#        'SeaLevelPress(hPa)low', 'Visibility(km)high', 'Visibility(km)avg',
#        'Visibility(km)low', 'Wind(km/h)low', 'Wind(km/h)avg', 'Wind(km/h)high',
#        'Precip(mm)sum', 'WeatherEvent'],
#       dtype='object')

# %%
# Drop 'Day' feature
weather_all.drop('Day', axis=1, inplace=True)

# %%
# Month lable replace with corresponding interger value
monthnum = {'Jan' : 1,  'Feb' : 2,  'Mar' : 3, 
            'Apr' : 4,  'May' : 5,  'Jun' : 6, 
            'Jul' : 7,  'Aug' : 8,  'Sep' : 9, 
            'Oct' : 10, 'Nov' : 11, 'Dec' : 12}

weather_all.Month = weather_all.Month.map(monthnum)

# View top 5 data
weather_all.head()
# Out:
#    Year  Month Temphigh(°C) Tempavg(°C) Templow(°C) DewPointhigh(°C)  \
# 0  2009      1           -3          -6          -9              -16
# 1  2009      1            1          -2          -5               -3
# 2  2009      1            3           1          -2               -5
# 3  2009      1            6           1          -4              -10
# 4  2009      1            6           5           3               -1
#
#   DewPointavg(°C) DewPointlow(°C) Humidity(%)high Humidity(%)avg     ...       \
# 0             -17             -19              54             43     ...
# 1              -7             -17              78             57     ...
# 2              -9             -13              72             54     ...
# 3             -12             -13              55             42     ...
# 4              -5             -16              62             48     ...
#
#   SeaLevelPress(hPa)avg SeaLevelPress(hPa)low Visibility(km)high  \
# ...

# %%
# Checking any missing values
print('BEFORE IMPUTE: \n', weather_all.isnull().sum())

# Replace '-' with 3.71 (Average value), 'T' with 11.19 (Average of Rain and Fog) and other missing values
weather_all['Precip(mm)sum'] = weather_all['Precip(mm)sum'].replace('-', 3.71)
weather_all['Precip(mm)sum'] = weather_all['Precip(mm)sum'].replace('T', 11.19)
weather_all['WeatherEvent'] = weather_all['WeatherEvent'].fillna('Others')

# Replace '-' with 0 value for other features
weather_all.iloc[:,2:21] = weather_all.iloc[:,2:21].replace('-', 0)

# Converting features data-type to Integer
weather_all.iloc[:,2:21] = weather_all.iloc[:,2:21].astype(int)

print('--------------------------------')

# Checking any missing values
print('AFTER IMPUTE: \n', weather_all.isnull().sum())
# Out:
# BEFORE IMPUTE:
#  Year                         0
# Month                        0
# Temphigh(°C)                 0
# Tempavg(°C)                  0
# Templow(°C)                  0
# DewPointhigh(°C)             0
# DewPointavg(°C)              0
# DewPointlow(°C)              0
# Humidity(%)high              0
# Humidity(%)avg               0
# Humidity(%)low               0
# SeaLevelPress(hPa)high       0
# SeaLevelPress(hPa)avg        0
# SeaLevelPress(hPa)low        0
# Visibility(km)high           0
# Visibility(km)avg            0
# Visibility(km)low            0
# Wind(km/h)low                0
# Wind(km/h)avg                0
# Wind(km/h)high               0
# Precip(mm)sum                0
# WeatherEvent              1908
# dtype: int64
# --------------------------------
# AFTER IMPUTE:
#  Year                      0
# Month                     0
# Temphigh(°C)              0
# Tempavg(°C)               0
# Templow(°C)               0
# DewPointhigh(°C)          0
# ...

# %%
# Separate Categorical and Numerical attributes
cat_att = ['Year', 'Month', 'WeatherEvent']
num_att = weather_all.columns.difference(cat_att)

# Change data-type of each attribute to proper data-type 
weather_all['Month'] = weather_all['Month'].astype('object')

# Change other Numeric features into Integer
weather_all[num_att] = weather_all[num_att].astype(float)

# %%
# Average value of each Numeric attributes group by 'Year' & 'Month' and storing in a new dataframe
weather_new = weather_all[['Year', 'Month', 'Temphigh(°C)', 'Tempavg(°C)', 'Templow(°C)', 'DewPointhigh(°C)',
                           'DewPointavg(°C)', 'DewPointlow(°C)', 'Humidity(%)high', 'Humidity(%)avg', 'Humidity(%)low',
                           'SeaLevelPress(hPa)high', 'SeaLevelPress(hPa)avg', 'SeaLevelPress(hPa)low', 'Visibility(km)high',
                           'Visibility(km)avg', 'Visibility(km)low', 'Wind(km/h)low', 'Wind(km/h)avg', 'Wind(km/h)high', 
                           'Precip(mm)sum']].groupby(['Year', 'Month'], as_index = False).mean().sort_values(by=['Year'], ascending=True)

# View dimension
weather_new.shape
# Out:
# (96, 21)

# %%
weather_new.head()
# Out:
#     Year  Month  Temphigh(°C)  Tempavg(°C)  Templow(°C)  DewPointhigh(°C)  \
# 0   2009      1      0.741935    -2.096774    -5.322581         -6.096774
# 11  2009     12      5.451613     2.354839    -1.032258         -0.935484
# 10  2009     11     13.733333    10.800000     7.566667          7.000000
# 9   2009     10     16.258065    12.870968     9.354839          9.838710
# 7   2009      8     27.967742    24.387097    20.548387         20.451613
#
#     DewPointavg(°C)  DewPointlow(°C)  Humidity(%)high  Humidity(%)avg  \
# 0         -9.903226       -14.000000        71.774194       57.354839
# 11        -4.677419        -8.709677        77.612903       61.741935
# 10         4.166667         1.433333        80.466667       66.600000
# 9          7.032258         3.903226        85.903226       69.354839
# 7         18.483871        16.129032        88.870968       72.483871
#
#         ...        SeaLevelPress(hPa)high  SeaLevelPress(hPa)avg  \
# ...

# %%
# Change the data-type of 'Year', 'Month' to Object type
weather_new[['Year', 'Month']] = weather_new[['Year', 'Month']].astype('object')

# %%
# Create na new column as 'Year_Month'
weather_new['Year_Month'] = weather_new.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)

weather_new.head(12)
# Out:
#     Year Month  Temphigh(°C)  Tempavg(°C)  Templow(°C)  DewPointhigh(°C)  \
# 0   2009     1      0.741935    -2.096774    -5.322581         -6.096774
# 11  2009    12      5.451613     2.354839    -1.032258         -0.935484
# 10  2009    11     13.733333    10.800000     7.566667          7.000000
# 9   2009    10     16.258065    12.870968     9.354839          9.838710
# 7   2009     8     27.967742    24.387097    20.548387         20.451613
# 6   2009     7     26.838710    22.741935    18.225806         18.838710
# 8   2009     9     22.766667    19.233333    15.333333         15.066667
# 4   2009     5     21.354839    17.000000    12.483871         12.967742
# 3   2009     4     17.100000    12.733333     7.833333          6.233333
# 2   2009     3      9.838710     5.967742     1.774194          0.258065
# 1   2009     2      6.964286     2.785714    -1.642857         -2.464286
# 5   2009     6     23.666667    19.866667    15.833333         17.100000
#
# ...

# %% [markdown]
# ##### Macro Economic Dataset

# %%
# Load the MacroEconomicData dataset
economy = pd.read_excel('MacroEconomicData.xlsx')

# %%
# Split the 'Year-Month' attribute to 'Year' and 'Month' attribute
economy['strDate'] = economy['Year-Month'].to_string(index=False).split('\n')
economy['Year'] = (economy['strDate'].str.split(' - ').str[0]).astype(int)
economy['Month'] = (economy['strDate'].str.split(' - ').str[1].str.slice(0, 3)).astype(str)

# drop
economy.drop(['strDate', 'Year-Month'], axis=1, inplace=True)

# %%
column = ['MonthlyNominalGDPIndex(inMillion$)', 'MonthlyRealGDPIndex(inMillion$)', 'CPI', 'PartyInPower', 'unemploymentrate', 'CommercialBankInterestRateonCreditCardPlans', 
           'FinanceRateonPersonalLoansatCommercialBanks(24MonthLoan)','Earningsorwagesindollarsperhour', 'AdvertisingExpenses(inThousandDollars)', 'CottonMonthlyPriceUScentsperPound(lbs)', 
           'Change(in%)', 'Averageuplandplanted(millionacres)', 'Averageuplandharvested(millionacres)', 'yieldperharvestedacre',
           'Production(in480lbnetwerightinmillionbales)', 'Mill use(in480lbnetwerightinmillionbales)', 'Exports','Year','Month']

economy = pd.DataFrame(economy.values, columns=column)

economy.dtypes
# Out:
# MonthlyNominalGDPIndex(inMillion$)                          object
# MonthlyRealGDPIndex(inMillion$)                             object
# CPI                                                         object
# PartyInPower                                                object
# unemploymentrate                                            object
# CommercialBankInterestRateonCreditCardPlans                 object
# FinanceRateonPersonalLoansatCommercialBanks(24MonthLoan)    object
# Earningsorwagesindollarsperhour                             object
# AdvertisingExpenses(inThousandDollars)                      object
# CottonMonthlyPriceUScentsperPound(lbs)                      object
# Change(in%)                                                 object
# Averageuplandplanted(millionacres)                          object
# Averageuplandharvested(millionacres)                        object
# yieldperharvestedacre                                       object
# ...

# %%
# Convert required attribute to Numeric data-type
num_data = ['MonthlyNominalGDPIndex(inMillion$)', 'MonthlyRealGDPIndex(inMillion$)', 'CPI', 'unemploymentrate',
               'CommercialBankInterestRateonCreditCardPlans', 'FinanceRateonPersonalLoansatCommercialBanks(24MonthLoan)',
               'Earningsorwagesindollarsperhour', 'CottonMonthlyPriceUScentsperPound(lbs)', 'Change(in%)',
               'Averageuplandplanted(millionacres)', 'Averageuplandharvested(millionacres)', 'yieldperharvestedacre',
               'Production(in480lbnetwerightinmillionbales)', 'Mill use(in480lbnetwerightinmillionbales)', 'Exports']

economy[num_data] = economy[num_data].astype(float)

# Data-type of each attribute
economy.dtypes
# Out:
# MonthlyNominalGDPIndex(inMillion$)                          float64
# MonthlyRealGDPIndex(inMillion$)                             float64
# CPI                                                         float64
# PartyInPower                                                 object
# unemploymentrate                                            float64
# CommercialBankInterestRateonCreditCardPlans                 float64
# FinanceRateonPersonalLoansatCommercialBanks(24MonthLoan)    float64
# Earningsorwagesindollarsperhour                             float64
# AdvertisingExpenses(inThousandDollars)                       object
# CottonMonthlyPriceUScentsperPound(lbs)                      float64
# Change(in%)                                                 float64
# Averageuplandplanted(millionacres)                          float64
# Averageuplandharvested(millionacres)                        float64
# yieldperharvestedacre                                       float64
# ...

# %%
# Re-label Months to Numeric values
monthnum = {'Jan' : 1,  'Feb' : 2,  'Mar' : 3, 'Apr' : 4,  'May' : 5,  'Jun' : 6, 
            'Jul' : 7,  'Aug' : 8,  'Sep' : 9, 'Oct' : 10, 'Nov' : 11, 'Dec' : 12}

economy.Month = economy.Month.map(monthnum)
economy.head()
# Out:
#    MonthlyNominalGDPIndex(inMillion$)  MonthlyRealGDPIndex(inMillion$)  \
# 0                        14421.752895                     14407.053343
# 1                        14389.200466                     14366.176571
# 2                        14340.701639                     14351.786822
# 3                        14326.815525                     14351.601731
# 4                        14345.904809                     14368.123959
#
#        CPI PartyInPower  unemploymentrate  \
# 0  233.402    Democrats               7.8
# 1  234.663    Democrats               8.3
# 2  235.067    Democrats               8.7
# 3  235.582    Democrats               9.0
# 4  235.975    Democrats               9.4
#
#    CommercialBankInterestRateonCreditCardPlans  \
# 0                                        12.03
# 1                                        12.97
# 2                                        12.97
# 3                                        12.97
# ...

# %%
# Create a new column as 'Year_Month'
economy['Year_Month'] = economy.apply(lambda x :'%s_%s' % (x['Year'], x['Month']), axis=1)

# View top 5 data
economy.head()
# Out:
#    MonthlyNominalGDPIndex(inMillion$)  MonthlyRealGDPIndex(inMillion$)  \
# 0                        14421.752895                     14407.053343
# 1                        14389.200466                     14366.176571
# 2                        14340.701639                     14351.786822
# 3                        14326.815525                     14351.601731
# 4                        14345.904809                     14368.123959
#
#        CPI PartyInPower  unemploymentrate  \
# 0  233.402    Democrats               7.8
# 1  234.663    Democrats               8.3
# 2  235.067    Democrats               8.7
# 3  235.582    Democrats               9.0
# 4  235.975    Democrats               9.4
#
#    CommercialBankInterestRateonCreditCardPlans  \
# 0                                        12.03
# 1                                        12.97
# 2                                        12.97
# 3                                        12.97
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
# View dimensions of each datasets
print(weather_new.shape)
print(economy.shape)
print(event.shape)
print(train_women.shape)
#print(train_men.shape)
#print(train_other.shape)
# Out:
# (96, 22)
# (96, 20)
# (96, 6)
# (84, 5)

# %% [markdown]
# #### Handling Missing Values

# %%
# Handle missing value
print('Weather Data:', weather_new.isna().sum().sum())
print('Economy Data:',economy.isna().sum().sum())
print('Event Data:', event.isna().sum().sum())
print('Train_women Data', train_women.isna().sum())      # Missing values
# Out:
# Weather Data: 0
# Economy Data: 0
# Event Data: 0
# Train_women Data Year               0
# Month              0
# ProductCategory    0
# Sales              4
# Year_Month         0
# dtype: int64

# %%
# Impute missing value
train_women = train_women.interpolate().bfill()

# Check again any missing value
train_women.isna().sum()
# Out:
# Year               0
# Month              0
# ProductCategory    0
# Sales              0
# Year_Month         0
# dtype: int64

# %% [markdown]
# #### Merge All data-sets

# %%
# Drop unnecessary columns
economy.drop(['Month', 'Year'], axis=1, inplace=True)
event.drop(['Month', 'Year'], axis=1, inplace=True)
train_women.drop(['Month', 'Year'], axis=1, inplace=True)

economy.drop(['AdvertisingExpenses(inThousandDollars)'], axis=1, inplace=True)

# %%
# Merge all datasets
data = pd.merge(pd.merge(pd.merge(weather_new, economy, on='Year_Month'), event, on='Year_Month'), train_women, on='Year_Month', how='left')

# Dimension
data.shape
# Out:
# (96, 43)

# %%
# Columns rename
data.rename(columns={'Temphigh(°C)' : 'Temphigh', 'Tempavg(°C)' : 'Tempavg', 'Templow(°C)' : 'Templow',
                     'DewPointhigh(°C)' : 'DewPointhigh', 'DewPointavg(°C)' : 'DewPointavg', 'DewPointlow(°C)' : 'DewPointlow',
                     'Humidity(%)high' : 'Humidityhigh', 'Humidity(%)avg' : 'Humidityavg', 'Humidity(%)low' : 'Humiditylow',
                     'SeaLevelPress(hPa)high' : 'SeaLevelPresshigh', 'SeaLevelPress(hPa)avg' : 'SeaLevelPressavg',
                     'SeaLevelPress(hPa)low' : 'SeaLevelPresslow', 'Visibility(km)high' : 'Visibilityhigh', 'Visibility(km)avg' : 'Visibilityavg',
                     'Visibility(km)low' : 'Visibilitylow', 'Wind(km/h)low' : 'Windlow', 'Wind(km/h)avg' : 'Windavg', 
                     'Wind(km/h)high' : 'Windhigh', 'Precip(mm)sum' : 'Precipsum', 'MonthlyNominalGDPIndex(inMillion$)' : 'MonthlyNominalGDPIndex', 
                     'MonthlyRealGDPIndex(inMillion$)' : 'MonthlyRealGDPIndex', 
                     'FinanceRateonPersonalLoansatCommercialBanks(24MonthLoan)' : 'FinanceRateonPersonalLoansatCommercialBanks',
                     'CottonMonthlyPriceUScentsperPound(lbs)' : 'CottonMonthlyPriceUScentsperPound', 'Change(in%)' : 'Change',
                     'Averageuplandplanted(millionacres)' : 'Averageuplandplanted', 'Averageuplandharvested(millionacres)' : 'Averageuplandharvested', 
                     'Production(in480lbnetwerightinmillionbales)' : 'Production',
                     'Mill use(in480lbnetwerightinmillionbales)' : 'Milluse', 'Federal Holiday' : 'FederalHoliday'}
                     , inplace=True)

# %% [markdown]
# #### Drop features based on Correlation

# %%
# Separate Categorical and Numeric attributes
cat_data = ['Year', 'Month', 'Year_Month', 'ProductCategory']
num_data = data.columns.difference(cat_data)

# Correlation Plot of Numeric attributes
sns.set(style="white")

corr = data[num_data].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 5, as_cmap=True)

corr.style.background_gradient().set_precision(2)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .3})

# %%
# Based on above correlation plot, drop highly correlated attributes
data.drop(['ProductCategory', 'Year_Month', 'DewPointhigh', 'DewPointlow', 
           'Humidityhigh', 'Humiditylow', 'SeaLevelPresshigh', 'SeaLevelPresslow', 'Windlow', 'Windhigh', 
           'MonthlyNominalGDPIndex', 'CPI', 'Earningsorwagesindollarsperhour', 'Production', 
           'FinanceRateonPersonalLoansatCommercialBanks', 'DewPointavg', 'Windavg', 'EventsCount', 'FederalHoliday', 
           'MonthlyRealGDPIndex', 'unemploymentrate', 'CommercialBankInterestRateonCreditCardPlans',
           'Exports', 'Temphigh', 'Templow', 'Tempavg', 'Visibilitylow', 'Milluse', 'Change', 'Visibilityhigh']
           , axis = 1, inplace = True)

# %%
# Separate Categorical and Numeric attributes
cat_data = ['Year', 'Month', 'Year_Month', 'ProductCategory']
num_data = data.columns.difference(cat_data)

# Correlation Plot of Numeric attributes
sns.set(style="white")

corr = data[num_data].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 5, as_cmap=True)

corr.style.background_gradient().set_precision(2)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .3}, annot=True)

# %% [markdown]
# #### Applying Standardization on Numeric features

# %%
# Train, Validation and Test data-sets
train_scaled = data.iloc[:72,:]
val_scaled = data.iloc[72:84,:]
test_scaled = data.iloc[84:,:]

# %%
data.drop('PartyInPower', axis=1, inplace=True)

# %%
# Seperate Categorical and Numric attributes
cat_col = ['Year', 'Month']
num_col = data.columns.difference(cat_col)

# Train data
train_cat = train_scaled[cat_col]
train_num = train_scaled[num_col]

# Validation data
val_cat = val_scaled[cat_col]
val_num = val_scaled[num_col]

# Test data
test_cat = test_scaled[cat_col]
test_num = test_scaled[num_col]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# Train data
train_num.drop('Sales', axis=1, inplace=True)
train_num_scaled = pd.DataFrame(scaler.fit_transform(train_num), columns=train_num.columns)

# Validation data
val_num.drop('Sales', axis=1, inplace=True)
val_num_scaled = pd.DataFrame(scaler.fit_transform(val_num), columns=val_num.columns, index=np.arange(72, 84, 1))

# Test data
test_num.drop('Sales', axis=1, inplace=True)
test_num_scaled = pd.DataFrame(scaler.fit_transform(test_num), columns=test_num.columns, index=np.arange(84, 96, 1))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
# Concatenate Categorical and Scaled Numeric DFs
train_scaled1 = pd.concat([train_cat, train_num_scaled], axis=1)
val_scaled1 = pd.concat([val_cat, val_num_scaled], axis=1)
test_scaled1 = pd.concat([test_cat, test_num_scaled], axis=1)

# %%
# Split Independent and Dependent features
X_train = train_scaled1.iloc[:,:]
y_train = train_scaled.loc[:,'Sales']

X_val = val_scaled1.iloc[:,:]
y_val = val_scaled.loc[:,'Sales']

# %%
# Dimension of all DFs
X_train.shape, y_train.shape, X_val.shape, y_val.shape, test_scaled1.shape
# Out:
# ((72, 11), (72,), (12, 11), (12,), (12, 11))

# %%
# Distribution of target 'Sales' attribute
from scipy.stats import norm
sns.distplot(train_scaled['Sales'], fit=norm, bins=10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Models Building

# %%
def mean_absolute_percentage_error(y_val, y_pred): 
    y_val, y_pred = np.array(y_val), np.array(y_pred)
    return np.mean(np.abs((y_val - y_pred) / y_val)) * 100

# %%
from sklearn.metrics import r2_score

def r_square(y_actual, y_prediction):
    return(r2_score(y_actual, y_prediction)*100)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

def rmse(y_actual, y_prediction):
    return(np.sqrt(mean_squared_error(y_actual, y_prediction)))

# %% [markdown]
# #### Linear Regression

# %%
model_lr = LinearRegression(n_jobs=-1)

#Fit
model_lr.fit(X_train, y_train)

# Prediction on Train data
y_pred_lm = model_lr.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_lm)
# Out:
# 8.065017087576164

# %%
# R-square 
print('Train R-squared: ', r_square(y_train, model_lr.predict(X_train)))
print('Val R-squared:   ', r_square(y_val, y_pred_lm))
# Out:
# Train R-squared:  82.24175499821251
# Val R-squared:    70.89581960471554

# %%
# R-square 
#train_r2 = r2_score(y_train, model_lr.predict(X_train))
#print('Train R-squared: ', train_r2*100)

#val_r2 = r2_score(y_val, y_pred_lm)
#print('Val R-squared:   ', val_r2*100)

# %%
# Root Mean Squared Error
print('Train RMSE: ', rmse(y_train, model_lr.predict(X_train)))
print('Val RMSE:   ', rmse(y_val, y_pred_lm))
# Out:
# Train RMSE:  330.8554876211073
# Val RMSE:    348.55781843422665

# %%
# Root Mean Squared Error
#train_rmse = np.sqrt(mean_squared_error(y_train, model_lr.predict(X_train)))
#print('Train RMSE: ', train_rmse)
      
#val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_lm))
#print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  330.8554876211073
# Val RMSE:    348.55781843422665

# %% [markdown]
# #### Decision Tree Regressor

# %%
model_dt = DecisionTreeRegressor(max_depth=4, criterion='mae', min_samples_leaf=0.11)

# Fit
model_dt.fit(X_train, y_train)

# Prediction on Train data
y_pred_dt = model_dt.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_dt)
# Out:
# 11.337954152754616

# %%
# R-square
train_r2 = r2_score(y_train, model_dt.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_pred_dt)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  55.580712286902376
# Val R-squared:    -1.8603899128718737

# %%
# Root Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_dt.predict(X_train)))
print('Train RMSE: ', train_rmse)
      
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_dt))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  523.2679265124767
# Val RMSE:    652.0783918875603

# %% [markdown]
# #### Random Forest Regressor

# %%
model_rf = RandomForestRegressor(max_depth=5, n_estimators=5000)    # 2 - Best

# Fit
model_rf.fit(X_train, y_train)

# Prediction on Train data
y_pred_rf = model_rf.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_rf)
# Out:
# 7.451481336491512

# %%
# R-square
train_r2 = r2_score(y_train, model_rf.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_pred_rf)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  95.29440307022611
# Val R-squared:    47.23434572077838

# %%
# Root Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_rf.predict(X_train)))
print('Train RMSE: ', train_rmse)
      
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_rf))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  170.3121700139953
# Val RMSE:    469.3240457294302

# %%
model_rf.fit(X_train, y_train)
feature_importances = pd.DataFrame(model_rf.feature_importances_, index = X_train.columns,
                                    columns=['Feature Importance']).sort_values('Feature Importance', ascending=False)
feature_importances.to_excel('Feature_Importances_RF2.xlsx')
feature_importances
# Out:
#                                    Feature Importance
# Year                                         0.307673
# Month                                        0.218757
# Event                                        0.139765
# CottonMonthlyPriceUScentsperPound            0.124195
# Averageuplandplanted                         0.076582
# SeaLevelPressavg                             0.037581
# Humidityavg                                  0.025636
# Averageuplandharvested                       0.018950
# Visibilityavg                                0.017969
# Precipsum                                    0.017446
# yieldperharvestedacre                        0.015448

# %% [markdown]
# #### Random Forest Regressor with RandomizedSearchCV

# %%
model_rf = RandomForestRegressor()

#hyper parameters set
rf_param = {'bootstrap': [True, False],
            'criterion' : ['mse', 'mae'],
            'n_estimators' : np.arange(500, 2000, 50),
            'max_features': ['auto', 'sqrt'],
            'max_depth': np.arange(2, 5, 1),
           }

model_rf_cv = RandomizedSearchCV(estimator=model_rf, param_distributions=rf_param, n_iter=10, n_jobs=-1, cv=10)

# Fit
model_rf_cv.fit(X_train, y_train)

# Prediction 
y_pred_rf_cv = model_rf_cv.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_rf_cv)
# Out:
# 8.364056299337323

# %%
model_rf_cv.best_params_
# Out:
# {'n_estimators': 850,
#  'max_features': 'auto',
#  'max_depth': 3,
#  'criterion': 'mae',
#  'bootstrap': True}

# %%
# R-square
train_r2 = r2_score(y_train, model_rf_cv.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_pred_rf_cv)
print('Val R-squared:  ', val_r2*100)
# Out:
# Train R-squared:  85.05188535174099
# Val R-squared:   28.371046816407485

# %%
# Root Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_rf_cv.predict(X_train)))
print('Train RMSE: ', train_rmse)

val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_rf_cv))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  303.55090405490796
# Val RMSE:    546.816290107792

# %% [markdown]
# #### Adaboost

# %%
model_ada = AdaBoostRegressor(n_estimators=5000, learning_rate=1, loss='exponential') # square, exponential

# Fit
model_ada.fit(X_train, y_train)

# Prediction
y_preds_ada = model_ada.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_preds_ada)
# Out:
# 6.528074798420596

# %%
# R-square
train_r2 = r2_score(y_train, model_ada.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_preds_ada)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  94.21898378546648
# Val R-squared:    59.45315017855418

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_ada.predict(X_train)))
print('Train RMSE: ', train_rmse)
   
# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_preds_ada))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  188.7732332447279
# Val RMSE:    411.41081230208613

# %% [markdown]
# #### Adaboost with RandomizedSearchCV

# %%
param_dist = {'n_estimators': np.arange(300, 3000, 100),
              'learning_rate' : [0.001, 0.01,0.05, 0.1, 0.5, 1],
              'loss' : ['linear', 'square', 'exponential']
             }

model_ada_cv = RandomizedSearchCV(AdaBoostRegressor(), param_distributions=param_dist,  cv=10,  n_iter=10, n_jobs=-1)
model_ada_cv.fit(X_train, y_train)

# Prediction
y_preds_ada_cv = model_ada_cv.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_preds_ada_cv)
# Out:
# 6.613369484641349

# %%
# R-square
train_r2 = r2_score(y_train, model_ada_cv.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_preds_ada_cv)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  94.27591504428206
# Val R-squared:    60.7896742025247

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_ada_cv.predict(X_train)))
print('Train RMSE: ', train_rmse)
      
val_rmse = np.sqrt(mean_squared_error(y_val, y_preds_ada_cv))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  187.84141712806505
# Val RMSE:    404.57343924109017

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
model_gbm = GradientBoostingRegressor(learning_rate=0.001, n_estimators=5000)
# Fit
model_gbm.fit(X_train, y_train)

# Prediction
y_pred_gbm = model_gbm.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_gbm)
# Out:
# 7.106242609288753

# %%
# R-square
train_r2 = r2_score(y_train, model_gbm.predict(X_train))
print('Train R-squared: ', train_r2*100)

val_r2 = r2_score(y_val, y_pred_gbm)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  99.3406676590175
# Val R-squared:    64.89337121893813

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_gbm.predict(X_train)))
print('Train RMSE: ', train_rmse)

# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_gbm))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  63.75151502601734
# Val RMSE:    382.8174318796689

# %% [markdown]
# #### Gradient Boosting Regressor with RandomizedSearchCV

# %%
gbm = GradientBoostingRegressor()

param_grid = {'learning_rate': [1, 0.5, 0.1, 0.2, 0.01, 0.001],
              'max_depth': np.arange(2, 9, 1),
              'max_features': np.arange(3, 6, 1),
              'max_leaf_nodes': np.arange(5, 10, 1),
              'n_estimators': np.arange(500, 3000, 100),
             }

gbm_rcv = RandomizedSearchCV(estimator=gbm, param_distributions=param_grid, n_iter=10, n_jobs=-1, cv=10)

# Fit
gbm_rcv.fit(X_train, y_train)

# Prediction
y_pred_gbm_cv = gbm_rcv.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_gbm_cv)
# Out:
# 5.856255281358828

# %%
gbm_rcv.best_estimator_
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.01, loss='ls', max_depth=8, max_features=4,
#              max_leaf_nodes=5, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=600, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
# R-square
train_r2 = r2_score(y_train, gbm_rcv.predict(X_train))
print('Train R-squared: ', train_r2*100)

# Validation
val_r2 = r2_score(y_val, y_pred_gbm_cv)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  98.97400648002855
# Val R-squared:    63.648971503513806

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, gbm_rcv.predict(X_train)))
print('Train RMSE: ', train_rmse)
   
# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_gbm_cv))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  79.52627296416348
# Val RMSE:    389.54307974898495

# %% [markdown]
# #### Support Vector Regressor

# %%
from sklearn.svm import SVR

model_svr = SVR(C=8, kernel='linear')

# Fit
model_svr.fit(X_train, y_train)

# Prediction
y_pred_svr = model_svr.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_svr)
# Out:
# 7.089903705472322

# %%
# R-square
train_r2 = r2_score(y_train, model_svr.predict(X_train))
print('Train R-squared: ', train_r2*100)

# Validation
val_r2 = r2_score(y_val, y_pred_svr)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  76.3811725870375
# Val R-squared:    58.00110833833133

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, model_svr.predict(X_train)))
print('Train RMSE: ', train_rmse)
   
# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_svr))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  381.5640826096182
# Val RMSE:    418.7126258397314

# %% [markdown]
# #### Support Vector Regressor with RandomizedSearchCV

# %%
model_svr_cv = SVR()
param_grid = {'C' : np.arange(1, 10, 0.01),
              'gamma' : [0.001, 0.01, 0.1, 1, 'auto'],
              'kernel' : ['linear', 'rbf'],
              'shrinking' : [True, False],
              'tol' : np.arange(0.1, 1, 0.1), 
              'epsilon' : np.arange(0.1, 1, 0.1)
             }

grid_search_svr = RandomizedSearchCV(model_svr_cv, param_grid, cv=10, n_iter=10, n_jobs=-1, random_state=12233)

# Fit
grid_search_svr.fit(X_train, y_train)

# Prediction
y_pred_svr_cv = grid_search_svr.predict(X_val)

# MAPE
mean_absolute_percentage_error(y_val, y_pred_svr_cv)
# Out:
# 7.108721482134256

# %%
grid_search_svr.best_params_
# Out:
# {'tol': 0.2,
#  'shrinking': False,
#  'kernel': 'linear',
#  'gamma': 0.001,
#  'epsilon': 0.5,
#  'C': 9.540000000000008}

# %%
# R-square
train_r2 = r2_score(y_train, grid_search_svr.predict(X_train))
print('Train R-squared: ', train_r2*100)

# Validation
val_r2 = r2_score(y_val, y_pred_svr_cv)
print('Val R-squared:   ', val_r2*100)
# Out:
# Train R-squared:  77.52788619222035
# Val R-squared:    60.90993405505666

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, grid_search_svr.predict(X_train)))
print('Train RMSE: ', train_rmse)
   
# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_pred_svr_cv))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  372.1862147284272
# Val RMSE:    403.9525402249005

# %% [markdown]
# #### XGBoost Regressor

# %%
X_train1 = X_train.drop(['Year', 'Month'], axis=1)
X_val1 = X_val.drop(['Year', 'Month'], axis=1)

# %%
# Scaling
scaler = StandardScaler()
X_train1_scaled = pd.DataFrame(scaler.fit_transform(X_train1), columns=X_train1.columns)
X_val1_scaled = pd.DataFrame(scaler.fit_transform(X_val1), columns=X_train1.columns)

# %%
xg_reg = xgb.XGBRegressor(objective='reg:linear', learning_rate=0.08, max_depth=2, n_estimators=5000, n_jobs=-1, 
                          random_state= 1266, subsample=0.5)
# Fit
xg_reg.fit(X_train1, y_train)

# Prediction
y_preds_xg = xg_reg.predict(X_val1)

# MAPE
mean_absolute_percentage_error(y_val, y_preds_xg)
# Out:
# 18.783249693962922

# %%
# R-square
train_r2 = r2_score(y_train, xg_reg.predict(X_train1))
print('Train R-squared: ', train_r2*100)

# Validation
val_r2 = r2_score(y_val, y_preds_xg)
print('Val R-squared: ', val_r2*100)
# Out:
# Train R-squared:  99.99999999949954
# Val R-squared:  -211.46533491939664

# %%
# Mean Squared Error
train_rmse = np.sqrt(mean_squared_error(y_train, xg_reg.predict(X_train1)))
print('Train RMSE: ', train_rmse)

# Validation
val_rmse = np.sqrt(mean_squared_error(y_val, y_preds_xg))
print('Val RMSE:   ', val_rmse)
# Out:
# Train RMSE:  0.0017564037941973192
# Val RMSE:    1140.2550412937435

# %%
# Final MAPE values from various models applied
MAPE_table = {'Linear Regression             '  : mean_absolute_percentage_error(y_val, y_pred_lm),
              'Decision Tree Regressor       '  : mean_absolute_percentage_error(y_val, y_pred_dt),
              'Random Forest Regressor       '  : mean_absolute_percentage_error(y_val, y_pred_rf),
              'Random Forest Regressor CV    '  : mean_absolute_percentage_error(y_val, y_pred_rf_cv),
              'Adaboost                      '  : mean_absolute_percentage_error(y_val, y_preds_ada),
              'Adaboost CV                   '  : mean_absolute_percentage_error(y_val, y_preds_ada_cv),
              'Gradient Boosting Regressor   '  : mean_absolute_percentage_error(y_val, y_pred_gbm),
              'Gradient Boosting Regressor CV'  : mean_absolute_percentage_error(y_val, y_pred_gbm_cv),
              'XGBoost Regressor             '  : mean_absolute_percentage_error(y_val, y_preds_xg)
             }

# Check the final accuracy table
MAPE_table
# Out:
# {'Linear Regression             ': 8.065017087576164,
#  'Decision Tree Regressor       ': 11.337954152754616,
#  'Random Forest Regressor       ': 7.451481336491512,
#  'Random Forest Regressor CV    ': 8.364056299337323,
#  'Adaboost                      ': 6.528074798420596,
#  'Adaboost CV                   ': 6.613369484641349,
#  'Gradient Boosting Regressor   ': 7.106242609288753,
#  'Gradient Boosting Regressor CV': 5.962777526747337,
#  'XGBoost Regressor             ': 18.783249693962922}

# %%
# Test - Prediction
y_test_pred = gbm_rcv.predict(test_scaled1)

######################## Final Submission ########################
#Submit the prediction
submission = pd.DataFrame({"Id" : np.arange(1, 13, 1), 
                           "Sales(In ThousandDollars)" : y_test_pred, 
                           "Year" : data['Year'][84:97],
                           "Month" : np.arange(1, 13, 1), 
                           "ProductCategory" : 'WomenClothing'
                          }, columns = ['Id', 'Sales(In ThousandDollars)', 'Year', 'Month', 'ProductCategory'])

submission.to_csv('Submission_File', index=False)

# %% [markdown]
# ### <center>END
